# %%
using Sigil
# Out:
# ┌ Info: Precompiling Sigil [e2d33801-af7e-4b31-8442-e621f8a5f6bc]
# └ @ Base loading.jl:1278
# ┌ Warning: Package Sigil does not have Plots in its dependencies:
# │ - If you have Sigil checked out for development and have
# │   added Plots as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with Sigil
# └ Loading Plots into Sigil from project dependency, future warnings for Sigil are suppressed.

# %%
star = Star(1*Msun)
# Out:
# Star(1.98e33, 1.98e31, 1.584e33, 0.7, 0.28, AbstractFloat[0.0], AbstractFloat[0.0], AbstractFloat[0.0], AbstractFloat[0.0], AbstractFloat[0.0])

# %%
shootf!(star)
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.050133e-16
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-15
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    298
#     f(x) calls:    527

# %%
Sigil.plot_star(star)
