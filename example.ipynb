# %%
using Pkg, Revise
Pkg.activate(".")

# %%
using Sigil
# Out:
# ┌ Info: Precompiling Sigil [e2d33801-af7e-4b31-8442-e621f8a5f6bc]
# └ @ Base loading.jl:1317

# %%
star = Star(1*Msun)#, "data/ModelS_struc.dat")
# Out:
# Star(1.989e33, 1.9890000000000001e31, 1.5912000000000003e33, 0.7, 0.28, AbstractFloat[0.0], AbstractFloat[0.0], AbstractFloat[0.0], AbstractFloat[0.0], AbstractFloat[0.0], "")

# %%
shootf!(star)
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     NaN
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≰ 1.0e-15
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    0
#     f(x) calls:    6

# %%
Sigil.plot_star(star)
